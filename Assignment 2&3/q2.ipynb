# %%
pip install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load audio file
audio_file = 'data/06.wav'
y, sr = librosa.load(audio_file)

# Extract chromagram
chromagram = librosa.feature.chroma_stft(y=y, sr=sr)

# Compute similarity matrix
similarity_matrix = np.dot(chromagram, chromagram.T)

# Plot chromagram
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.show()

# Plot similarity matrix
plt.figure(figsize=(8, 8))
plt.imshow(similarity_matrix, origin='lower', cmap='viridis')
plt.colorbar()
plt.title('Similarity Matrix')
plt.show()

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load audio file
audio_file = 'data/05.wav'
y, sr = librosa.load(audio_file)

# Extract chromagram
chromagram = librosa.feature.chroma_stft(y=y, sr=sr)

# Compute similarity matrix
similarity_matrix = np.dot(chromagram, chromagram.T)

# Plot chromagram
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.show()

# Plot similarity matrix
plt.figure(figsize=(8, 8))
plt.imshow(similarity_matrix, origin='lower', cmap='viridis')
plt.colorbar()
plt.title('Similarity Matrix')
plt.show()

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load audio file
audio_file = 'data/04.wav'
y, sr = librosa.load(audio_file)

# Extract chromagram
chromagram = librosa.feature.chroma_stft(y=y, sr=sr)

# Compute similarity matrix
similarity_matrix = np.dot(chromagram, chromagram.T)

# Plot chromagram
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.show()

# Plot similarity matrix
plt.figure(figsize=(8, 8))
plt.imshow(similarity_matrix, origin='lower', cmap='viridis')
plt.colorbar()
plt.title('Similarity Matrix')
plt.show()

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load audio file
audio_file = 'data/03.wav'
y, sr = librosa.load(audio_file)

# Extract chromagram
chromagram = librosa.feature.chroma_stft(y=y, sr=sr)

# Compute similarity matrix
similarity_matrix = np.dot(chromagram, chromagram.T)

# Plot chromagram
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.show()

# Plot similarity matrix
plt.figure(figsize=(8, 8))
plt.imshow(similarity_matrix, origin='lower', cmap='viridis')
plt.colorbar()
plt.title('Similarity Matrix')
plt.show()

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load audio file
audio_file = 'data/02.wav'
y, sr = librosa.load(audio_file)

# Extract chromagram
chromagram = librosa.feature.chroma_stft(y=y, sr=sr)

# Compute similarity matrix
similarity_matrix = np.dot(chromagram, chromagram.T)

# Plot chromagram
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.show()

# Plot similarity matrix
plt.figure(figsize=(8, 8))
plt.imshow(similarity_matrix, origin='lower', cmap='viridis')
plt.colorbar()
plt.title('Similarity Matrix')
plt.show()

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load audio file
audio_file = 'data/01.wav'
y, sr = librosa.load(audio_file)

# Extract chromagram
chromagram = librosa.feature.chroma_stft(y=y, sr=sr)

# Compute similarity matrix
similarity_matrix = np.dot(chromagram, chromagram.T)

# Plot chromagram
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chromagram')
plt.show()

# Plot similarity matrix
plt.figure(figsize=(8, 8))
plt.imshow(similarity_matrix, origin='lower', cmap='viridis')
plt.colorbar()
plt.title('Similarity Matrix')
plt.show()
